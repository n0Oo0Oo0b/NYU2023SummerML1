# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# dataframe - df
df = pd.read_csv('https://raw.githubusercontent.com/ajn313/NYU2023SummerML1/main/Day2/NYU23SummerML1_movie.csv')
# df = df.dropna()

# %%
df.head(20)
# Out:
#                      Name  Rising Grade (Number)              Town  \
# 0     Harrison DiAmbrosio                     12     Montclair, NJ
# 1            Kaitlyn Park                     10      Wesfield, IN
# 2             Armaan Goel                     11   Gainesville, FL
# 3             Tiffany Tan                     11          Troy, MI
# 4        Kaustubh Duddala                     12        Dallas, TX
# 5           Sahar Elkalai                     12       Amherst, MA
# 6               Owen Wang                     11         Acton, MA
# 7              Teddy Bach                     10    New Canaan, CT
# 8            Pavel Hardey                     12      St.Louis, MO
# 9           Nastia Belova                     11   Lake Forest, IL
# 10          Riccardo Bean                     12      New York, NY
# 11         Caiden Hibbert                     12            London
# 12  Christina L'Hommedieu                     11      Columbus, OH
# 13          Sarah Schafer                     12       Teaneck, NJ
# 14       Emmy Goncheroski                     12  Philadelphia, PA
# 15     Prima Changwatchai                     11        Austin, TX
# 16               Eric Fan                     11      St.Louis, MO
# 17               Nia Tran                     12   Los Angeles, CA
# 18              Daniel Gu                     11          Shanghai
# 19         Batu Sinanoglu                     12    Abu Dhabi, UAE
#
#                          Movie             Category  IMDB Rating  \
# 0     The Little Prince (1972)               Family          6.3
# 1                Black Panther               Action          7.3
# 2                       Amélie              Romance          7.3
# 3   10 Things I Hate About You               Comedy          7.3
# 4                 Interstellar               Sci-Fi          8.7
# 5              The Incredibles        Family/action          8.0
# 6                   Home Alone        Family/Comedy          7.7
# 7       Penguins of Madagascar            Adventure          6.6
# 8                  Ratatouille            Adventure          8.0
# 9                   Knives Out       mystery/comedy          7.9
# 10              Murder Mystery       Mystery/Action          6.1
# 11             Ford vs Ferrari          Sport/Drama          8.1
# 12         Pride and Prejudice                Drama          7.8
# 13                Molly's Game                Drama          7.4
# 14                   Gone Girl                Drama          8.1
# 15    The Shawshank Redemption                Drama          9.3
# 16                Ratatouille             Adventure          8.1
# 17                Coach Carter                Drama          7.3
# 18                  Your Name.            Animation          8.4
# 19                        Cats  Comedy/Drama/Family          2.8
#
#     Coding experience (1-5)
# 0                       3.5
# 1                       3.0
# 2                       3.0
# 3                       2.0
# 4                       3.0
# 5                       2.0
# 6                       4.5
# 7                       3.0
# 8                       3.0
# 9                       3.0
# 10                      4.0
# 11                      2.0
# 12                      3.7
# 13                      2.0
# 14                      3.5
# 15                      2.5
# 16                      2.4
# 17                      3.0
# 18                      4.8
# 19                      3.0

# %% [markdown]
# ### Plot the IMDB scores for all the movies
# - Use the [plt.scatter() function](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.scatter.html)
# - x-axis indicates the name of the movies, y-axis shows the score.
# - do not forget to put on the labels for the axes.

# %%
score = df['IMDB Rating'].values
names = df['Movie'].values
values = sorted(zip(names, score), key=lambda x: x[1])

# %%
## To-do
plt.figure(figsize=(15, 5))
plt.scatter(*zip(*values))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Plot the number of movies for each genre
# - Use the [`plt.bar()` function](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.bar.html)
# - x-axis indicates the genre, y-axis shows the count for each genre.
# - do not forget to put on the labels for the axes.

# %%
# To-do
genre = df['Category'].values
modes, counts = np.unique(genre, return_counts=True)

# %%
from collections import Counter

values = Counter()
for genre in df['Category'].values:
    values.update(genre.split('/'))
print(values)
# Out:
# Counter({'Drama': 7, 'Family': 4, 'Action': 4, 'Comedy': 3, 'Adventure': 3, 'Romance': 1, 'Sci-Fi': 1, 'action': 1, 'mystery': 1, 'comedy': 1, 'Mystery': 1, 'Sport': 1, 'Animation': 1})

# %%
plt.figure(figsize=(15, 5))
plt.bar(*zip(*values.items()))
plt.xticks(modes, rotation=90)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Plot the histogram for the IMDB score
# - Use [plt.hist() function](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html)
# - x-axis indicates the score interval, y-axis shows the number of movies within each score interval
# - make the interval length 0.5
# - do not forget to put on the labels for the axes.

# %% [markdown]
# - numpy arange() might come in handy!

# %%
# To-do
min_score = np.min(score)
max_score = np.max(score)

bin_range = np.arange(min_score, max_score, 0.5)
plt.hist(score, bin_range, ec='red')

plt.xlabel('Score')
plt.ylabel('Number')
plt.show()

# %% [markdown]
# ### Calculate the mean and variance of the IMDB score of the movies

# %%
# To-do
mean_score = np.mean(score)
var_score = np.var(score)

print("Mean score: ", mean_score)
print("Var of score: ", var_score)
# Out:
# Mean score:  7.318181818181819
# Var of score:  1.6578512396694216
